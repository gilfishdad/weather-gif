# %%
import os
import requests
from datetime import datetime

def download_image(url, save_path):
    try:
        response = requests.get(url, stream=True, headers={"User-Agent": "Mozilla/5.0"})
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Image {save_path} downloaded successfully.")
        else:
            print(f"Error {response.status_code}: Unable to download image from {url}")
    except Exception as e:
        print(f"Error: {e}")


def main():
    # Placeholder for the list of URLs. You'll need to populate this list dynamically based on your method of identifying today's GIFs.
    todays_gif_urls = [
         'https://www.wpc.ncep.noaa.gov/sfc/sfcobs/small_latestsfcwc.gif',
         'https://www.wpc.ncep.noaa.gov/sfc/ussatsfc.gif',
         #'https://www.wpc.ncep.noaa.gov/basicwx/bwxloop_ndfd.html'@ fail wont download running html gif
        'https://www.wpc.ncep.noaa.gov/basicwx/91fndfd.gif',
        'https://cdn.star.nesdis.noaa.gov/GOES16/ABI/CONUS/GEOCOLOR/10000x6000.jpg'
        # Add more URLs as needed
    ]
    
    # Get the current date and time
    
    folder_name = now.strftime("%A_%H%M_%d%m%Y")  # Format: day_of_week_time_date
    
    # Create the folder with the current date and time
    image_folder = os.path.join("images", folder_name)
    os.makedirs(image_folder, exist_ok=True)

    for url in todays_gif_urls:
        filename = os.path.basename(url)  # Extracts filename from URL
        save_path = os.path.join(image_folder, filename)
        download_image(url, save_path)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 44
#      41         download_image(url, save_path)
#      43 if __name__ == "__main__":
# ---> 44     main()
#
# Cell In[1], line 32, in main()
#      21 todays_gif_urls = [
#      22      'https://www.wpc.ncep.noaa.gov/sfc/sfcobs/small_latestsfcwc.gif',
#      23      'https://www.wpc.ncep.noaa.gov/sfc/ussatsfc.gif',
#    (...)
#      27     # Add more URLs as needed
#      28 ]
#      30 # Get the current date and time
# ---> 32 folder_name = now.strftime("%A_%H%M_%d%m%Y")  # Format: day_of_week_time_date
#      34 # Create the folder with the current date and time
#      35 image_folder = os.path.join("images", folder_name)
#
# NameError: name 'now' is not defined

# %%
import os
import requests
from datetime import datetime

def download_image(url, save_path):
    try:
        response = requests.get(url, stream=True, headers={"User-Agent": "Mozilla/5.0"})
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Image {save_path} downloaded successfully.")
        else:
            print(f"Error {response.status_code}: Unable to download image from {url}")
    except Exception as e:
        print(f"Error: {e}")

def main():
    # Placeholder for the list of URLs. You'll need to populate this list dynamically based on your method of identifying today's GIFs.
    todays_gif_urls = [
         'https://www.wpc.ncep.noaa.gov/sfc/sfcobs/small_latestsfcwc.gif',
         'https://www.wpc.ncep.noaa.gov/sfc/ussatsfc.gif',
         #'https://www.wpc.ncep.noaa.gov/basicwx/bwxloop_ndfd.html'@ fail wont download running html gif
        'https://www.wpc.ncep.noaa.gov/basicwx/91fndfd.gif',
        'https://www.wpc.ncep.noaa.gov/html/sfc-zoom.php'
        # Add more URLs as needed
    ]
    
    # Get the current date and time
    now = datetime.now()
    folder_name = now.strftime("%A_%H%M_%d%m%Y")  # Format: day_of_week_time_date
    
    # Create the folder with the current date and time
    image_folder = os.path.join("images", folder_name)
    os.makedirs(image_folder, exist_ok=True)

    for url in todays_gif_urls:
        filename = os.path.basename(url)  # Extracts filename from URL
        save_path = os.path.join(image_folder, filename)
        download_image(url, save_path)

if __name__ == "__main__":
    main()

# %% [markdown]
# # Download weather.gov images

# %%
#download latest images from weather.gov

import os
import requests
from datetime import datetime

def download_image(url, save_path):
    try:
        response = requests.get(url, stream=True, headers={"User-Agent": "Mozilla/5.0"})
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            print(f"Image {save_path} downloaded successfully.")
        else:
            print(f"Error {response.status_code}: Unable to download image from {url}")
    except Exception as e:
        print(f"Error: {e}")

def main():
    # Placeholder for the list of URLs. You'll need to populate this list dynamically based on your method of identifying today's GIFs.
    todays_gif_urls = [
         'https://www.wpc.ncep.noaa.gov/sfc/sfcobs/small_latestsfcwc.gif',
         'https://www.wpc.ncep.noaa.gov/sfc/ussatsfc.gif',
         #'https://www.wpc.ncep.noaa.gov/basicwx/bwxloop_ndfd.html'@ fail wont download running html gif
        'https://www.wpc.ncep.noaa.gov/basicwx/91fndfd.gif',
        #'https://cdn.star.nesdis.noaa.gov/GOES16/ABI/CONUS/GEOCOLOR/10000x6000.jpg',
        'https://cdn.star.nesdis.noaa.gov/GOES16/ABI/CONUS/GEOCOLOR/5000x3000.jpg'
        # Add more URLs as needed
    ]
    
    # Get the current date and time
    now = datetime.now()
    folder_name = now.strftime("%A_%H%M_%d%m%Y")  # Format: day_of_week_time_date
    
    # Create the folder with the current date and time
    image_folder = os.path.join("images", folder_name)
    os.makedirs(image_folder, exist_ok=True)

    for url in todays_gif_urls:
        filename = os.path.basename(url)  # Extracts filename from URL
        save_path = os.path.join(image_folder, filename)
        download_image(url, save_path)

if __name__ == "__main__":
    main()
# Out:
# Image images/Wednesday_1156_17072024/small_latestsfcwc.gif downloaded successfully.
# Image images/Wednesday_1156_17072024/ussatsfc.gif downloaded successfully.
# Image images/Wednesday_1156_17072024/91fndfd.gif downloaded successfully.
# Image images/Wednesday_1156_17072024/5000x3000.jpg downloaded successfully.

# %%
import os
import requests
from datetime import datetime

# Creating the transaction data for the new statement period
data_new = {
    "Date": [
        "02/04/2021", "02/04/2021", "02/09/2021", "02/18/2021",
        "03/01/2021", "03/01/2021", "03/04/2021", "03/04/2021", "03/04/2021"
    ],
    "Description": [
        "Beginning Balance", "ACH DEP DFAS-CLEVELAND FED SALARY",
        "CHECK #1079", "ACH DEP DFAS-CLEVELAND FED SALARY",
        "USAA Funds Transfer DB to Thomas Gilmore", "ACH Withdrawal AMEX EPAYMENT ACH PMT",
        "ACH DEP DFAS-CLEVELAND FED SALARY", "Interest Paid", "Ending Balance"
    ],
    "Amount": [
        "$844.31", "$1,335.74", "-$200.00", "$1,335.73",
        "-$300.00", "-$19.05", "$1,335.74", "$0.02", "$4,332.49"
    ]
}

# Creating a DataFrame for the new data
df_new = pd.DataFrame(data_new)

# Saving to a CSV file
csv_file_path_new = '/mnt/data/transaction_list_new.csv'
df_new.to_csv(csv_file_path_new, index=False)

import ace_tools as tools; tools.display_dataframe_to_user(name="Transaction List New", dataframe=df_new)

df_new, csv_file_path_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m5/ndxqhcc15nx0trmvr87xf7j80000gn/T/ipykernel_32940/1224962102.py in <module>
#      18
#      19 # Creating a DataFrame for the new data
# ---> 20 df_new = pd.DataFrame(data_new)
#      21
#      22 # Saving to a CSV file
#
# NameError: name 'pd' is not defined
